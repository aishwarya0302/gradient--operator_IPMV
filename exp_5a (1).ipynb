# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread('/content/Ganeshji.jpeg', cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found!")
    exit()

# Apply the Sobel operator to find the gradient in the x and y directions
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)  # Gradient in the x direction (horizontal edges)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)  # Gradient in the y direction (vertical edges)
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread('/content/Ganeshji.jpeg', cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found!")
    exit()

# Apply the Sobel operator to find the gradient in the x and y directions
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)  # Gradient in the x direction (horizontal edges)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)  # Gradient in the y direction (vertical edges)

# Compute the magnitude of the gradient (edge strength)
gradient_magnitude = np.sqrt(sobel_x**2 + sobel_y**2)
# Out:
#   File "<ipython-input-3-9bc71a7ced5f>", line 18
#     gradient_magnitude =
#                          ^
# SyntaxError: invalid syntax

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread('/content/Ganeshji.jpeg', cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded properly
if image is None:
    print("Error: Image not found!")
    exit()

# Apply the Sobel operator to find the gradient in the x and y directions
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)  # Gradient in the x direction (horizontal edges)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)  # Gradient in the y direction (vertical edges)

# Compute the magnitude of the gradient (edge strength)
gradient_magnitude = cv2.magnitude(sobel_x, sobel_y)

# Convert the gradient magnitude to an 8-bit image (for visualization)
gradient_magnitude = cv2.convertScaleAbs(gradient_magnitude)

# Display the original and processed images
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')

plt.subplot(1, 3, 2)
plt.title('Sobel X Gradient')
plt.imshow(sobel_x, cmap='gray')

plt.subplot(1, 3, 3)
plt.title('Gradient Magnitude (Edges)')
plt.imshow(gradient_magnitude, cmap='gray')

plt.show()
